# %% [markdown]
# <a href="https://colab.research.google.com/github/tugcegulsanusta/nlp-homeworks/blob/master/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extract Data

# %%
pip install -qU langchain-text-splitters

# %%
pip install qdrant-client

# %%
pip install pypdf

# %%
from pypdf import PdfReader
#give a path from your local.
FILE_PATH = r"/content/sample_data/random-essay.pdf"
reader = PdfReader(FILE_PATH)
number_of_pages = len(reader.pages)
entire_text= ""
for page_num in range(number_of_pages):
    page = reader.pages[page_num]
    entire_text += page.extract_text()

entire_text[:200]
# Out:
# 'random.org : Introduction to Randomness and Random Numbers\nMads Haahr\nJune 1999*\nBackground\nOh, many a shaft at random sent\nFinds mark the archer little meant!\nAnd many a word at random spoken\nMay soo'

# %% [markdown]
# ## Split Text

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
text_chunks = text_splitter.split_text(entire_text)
print(f"Total chunks: {len(text_chunks)}")
# Out:
# Total chunks: 23

# %%
text_chunks[:2]
# Out:
# ['random.org : Introduction to Randomness and Random Numbers\nMads Haahr\nJune 1999*\nBackground\nOh, many a shaft at random sent\nFinds mark the archer little meant!\nAnd many a word at random spoken\nMay soothe, or wound, a heart that’s broken!”\n— Sir Walter Scott\nRandomness and random numbers have traditionally been used for a variety of purposes, for ex-\nample games such as dice games. With the advent of computers, people recognized the need for a',
#  'means of introducing randomness into a computer program. Surprising as it may seem, however,\nit is diﬃcult to get a computer to do something by chance. A computer running a program follows\nits instructions blindly and is therefore completely predictable.\nComputer engineers chose to introduce randomness into computers in the form of pseudo-\nrandom number generators. As the name suggests, pseudo-random numbers are not truly random.']
